# %%
import random
import os

# %%
# 100까지의 숫자 중 임의의 정수를 구한다.
defaultint = random.randint(0,100)                  # 0에서 100까지 수중 임의의 수를 구함

# %%
path= "makedir_test"
if not os.path.isdir(path):
    os.mkdir(path)

# %%
print(os.getcwd())
# Out:
# /content
