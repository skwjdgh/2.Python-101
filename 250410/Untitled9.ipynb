# %%
import random

# %%
throw1 = 0
throw2 = 0
throw3 = 0
sum = 0
total = 0

# %%
# 1프레임 설계
currentframe = frame + 1

# 키는 1프레임

#실제 프레임은 0이나 표현식은 1이다.
throw1 = random.randint(0,10)
if throw1 == 10:
    sum = throw1
    total = total + sum

else:
    temprange = 10 - throw1
    throw2 = random.randint(0, temprange)
    sum = throw1 + throw2
    total = total + sum

    for past in range(frame - 2,frame)  # -2 -1 프레임 0이므로 -2, -1 값 생성
        # 키는 -1프레임, 0프레임

        # pastframe  키값으로 표현한다면 past+1로 표현하면 됨 -1 , 0프레임
        # 즉, 조건은 past+1 <= 0으로 값을 표기해야함
        # 키값에 따른 프레임이 상태값이 0보다 클 경우
        # -2에서의 sum에서 throw1 값을 더함
        # -1에서의 sum에서 throw1 값을 더함

# %%
# result에 1 ~ 10 각 프레임의 값을 표기하고 총점을 기록하는 것!
# 점수는 랜덤으로 5개의 값을 생성한다.
#
