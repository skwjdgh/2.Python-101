# %%
import constant1
constant1.path.append()
print(constant1.PI)
print(constant1.GRAVITY)
constant1.PI = 3.141592
print(constant1.PI)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e9c6f9bd19be> in <cell line: 0>()
# ----> 1 import constant1
#       2 print(constant1.PI)
#       3 print(constant1.GRAVITY)
#       4 constant1.PI = 3.141592
#       5 print(constant1.PI)
#
# ModuleNotFoundError: No module named 'constant1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
d= "\"python\""
print(d)
# Out:
# "python"
