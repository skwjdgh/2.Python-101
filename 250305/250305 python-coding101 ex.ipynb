# %% [markdown]
# 수업 예제 및 메모리 할당 테스트

# %%
a = 10
for i in range(a): #타입을 설명해주는 주석, 런타임의 '런타임 유형'에서 gpu 사용시 중단될 가능성이 큼
    print(i)

# %% [markdown]
# 타입을 설명해주는 주석,
# *알아둘 것: 런타임의 '런타임 유형'에서 gpu 사용시 중단될 가능성이 큼

# %%
b = 20
c = a + b
print(c)

# %% [markdown]
# +코드는 새로운 셀,+텍스트는 마크다운을 사용하게함

# %%
a=20

# %%
c=a+b
print(c)

# %% [markdown]
# 중간에 수식을 추가할 경우, 이미 실행하여 결과값을 구했을 경우, 원하는 값이 나오지 않음

# %%
import math
>>> math.factorial(5)
# Out:
# 120

# %%
c=1

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   32G   77G  30% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# /dev/sda1        80G   64G   17G  80% /kaggle/input
# tmpfs           6.4G  2.1M  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
id(c)
# Out:
# 10752104

# %%
id(1)
# Out:
# 10750856

# %%
d=12
id(d)
# Out:
# 10751208

# %%
id(12)
# Out:
# 10751208

# %%
# !python --version
# Out:
# Python 3.11.11
