# %%
a={5,2,3,1,4}
print(a)
print(type(a))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_set = {1,3}
print(my_set)
my_set.update([2,3,4])
print(my_set)
# Out:
# {1, 3}
# {1, 2, 3, 4}

# %%
d= {1:'value', 'key':2}
print(d[1]) # 인덱스와 헷갈릴 수 있음
# print(d[2])는 오류남
# Out:
# value

# %%
 num_int=123
 num_str="456"
 print("Datatypeofnum_int:", type(num_int))
 print("Datatypeofnum_strbefore Type Casting:", type(num_str))
 num_str=int(num_str)
 print("Datatypeofnum_strafterTypeCasting:", type(num_str))
 num_sum=num_int +num_str
 print("Sumofnum_intandnum_str:", num_sum)
 print("Datatypeofthesum:", type(num_sum))
# Out:
# Datatypeofnum_int: <class 'int'>
# Datatypeofnum_strbefore Type Casting: <class 'str'>
# Datatypeofnum_strafterTypeCasting: <class 'int'>
# Sumofnum_intandnum_str: 579
# Datatypeofthesum: <class 'int'>

# %%
print(123123123,end='\n', sep='123',)
print("b")
# Out:
# 123123123
# b

# %%
print('i love {1} and {0}'.format('bread','butter')) #인덱스를 사용해서 표현할 수 있다print('i love {1} and {0}'.format('bread','butter')) #인덱스를 사용해서 표현할 수 있다
# Out:
# i love butter and bread

# %%
x = 12.3456789
print('The value of x is %3.2f' %x)
# Out:
# The value of x is 12.35

# %%
num = input('Enter a number: ')
print(num)
print(type(num))
num1 = int(num) + 1
print(num1)
# Out:
# Enter a number: 메롱
# 메롱
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ac0c44839f52> in <cell line: 0>()
#       2 print(num)
#       3 print(type(num))
# ----> 4 num1 = int(num) + 1
#       5 print(num1)
#
# ValueError: invalid literal for int() with base 10: '메롱'

# %%
num = input('Enter a number: ')
print(num)
print(type(num))
# Out:
# Enter a number: 메롱
# 메롱
# <class 'str'>

# %%
import math #전체를 다 가져옴
print(math.pi)
# Out:
# 3.141592653589793

# %%
from math import pi #math라는 모듈에서 pi라는 값만 가져옴, math 전체가 아님
pi #pi를 변수처럼 사용하면 안됨
pi=1

# %%
a= True
b= False
c= True
print(x and b and c)
# Out:
# False
